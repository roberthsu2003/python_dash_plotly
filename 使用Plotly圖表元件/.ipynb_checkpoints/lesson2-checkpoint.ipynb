# %%
import pandas as pd
#查人口
proverty_data = pd.read_csv('PovStatsData.csv')
# Out:
#                                        Country Name Country Code  \
# 300  IDA countries classified as fragile situations          DFS
# 301  IDA countries classified as fragile situations          DFS
# 302  IDA countries classified as fragile situations          DFS
# 303  IDA countries classified as fragile situations          DFS
# 304  IDA countries classified as fragile situations          DFS
# 305  IDA countries classified as fragile situations          DFS
# 306  IDA countries classified as fragile situations          DFS
# 307  IDA countries classified as fragile situations          DFS
# 308  IDA countries classified as fragile situations          DFS
# 309  IDA countries classified as fragile situations          DFS
# 310  IDA countries classified as fragile situations          DFS
# 311  IDA countries classified as fragile situations          DFS
# 312  IDA countries classified as fragile situations          DFS
# ...

# %%
regions = ['East Asia & Pacific', 'Europe & Central Asia',
           'Fragile and conflict affected situations', 'High income',
           'IDA countries classified as fragile situations',
           'IDA total', 'Latin America & Caribbean', 'Low & middle income',
           'Low income', 'Lower middle income', 'Middle East & North Africa',
           'Middle income', 'South Asia', 'Sub-Saharan Africa',
           'Upper middle income', 'World','West Bank and Gaza']

# %%
population_df = proverty_data[~proverty_data['Country Name'].isin(regions) & (proverty_data['Indicator Name']=='Population, total')]
population_df
# Out:
#         Country Name Country Code     Indicator Name Indicator Code  \
# 1051     Afghanistan          AFG  Population, total    SP.POP.TOTL
# 1115         Albania          ALB  Population, total    SP.POP.TOTL
# 1179         Algeria          DZA  Population, total    SP.POP.TOTL
# 1243          Angola          AGO  Population, total    SP.POP.TOTL
# 1307       Argentina          ARG  Population, total    SP.POP.TOTL
# ...              ...          ...                ...            ...
# 11483  Venezuela, RB          VEN  Population, total    SP.POP.TOTL
# 11547        Vietnam          VNM  Population, total    SP.POP.TOTL
# 11675    Yemen, Rep.          YEM  Population, total    SP.POP.TOTL
# 11739         Zambia          ZMB  Population, total    SP.POP.TOTL
# 11803       Zimbabwe          ZWE  Population, total    SP.POP.TOTL
#
#              1974        1975        1976        1977        1978        1979  \
# ...

# %%
year = '2010'
year_df = population_df[['Country Name', year]].sort_values(year,ascending=False)[:20]
year_df
# Out:
#              Country Name          2010
# 2907                China  1.337705e+09
# 5339                India  1.234281e+09
# 11227       United States  3.093261e+08
# 5403            Indonesia  2.418342e+08
# 2203               Brazil  1.957136e+08
# 8347             Pakistan  1.794246e+08
# 8155              Nigeria  1.585032e+08
# 1627           Bangladesh  1.475754e+08
# 8987   Russian Federation  1.428494e+08
# 5851                Japan  1.280700e+08
# 7323               Mexico  1.140930e+08
# 8731          Philippines  9.396678e+07
# 11547             Vietnam  8.796765e+07
# 4187             Ethiopia  8.763996e+07
# 3803     Egypt, Arab Rep.  8.276124e+07
# 4635              Germany  8.177693e+07
# 5467   Iran, Islamic Rep.  7.376252e+07
# 10843              Turkey  7.232699e+07
# 10459            Thailand  6.719503e+07
# 4379               France  6.502751e+07

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_bar(
    x=year_df['Country Name'],
    y=year_df[year]
)
fig.update_layout(title_text=f'最多人口的20國家-{year}')
fig.show()
# Out:
#   Input In [19]
#     import plotly.graph_objects import go
#                                 ^
# SyntaxError: invalid syntax
