# %%
import datasource
import pandas as pd

lastest_data = datasource.lastest_datetime_data()
lastest_df = pd.DataFrame(lastest_data,columns=['站點名稱','更新時間','行政區','地址','總數','可借','可還'])
df1 = lastest_df.iloc[[1]]
[{"name": i, "id": i} for i in df1.columns]
# Out:
# [{'name': '站點名稱', 'id': '站點名稱'},
#  {'name': '更新時間', 'id': '更新時間'},
#  {'name': '行政區', 'id': '行政區'},
#  {'name': '地址', 'id': '地址'},
#  {'name': '總數', 'id': '總數'},
#  {'name': '可借', 'id': '可借'},
#  {'name': '可還', 'id': '可還'}]

# %%
lastest_df1 = lastest_df.reset_index()
lastest_df1['站點名稱'] = lastest_df1['站點名稱'].map(lambda name:name[11:])

# %%
lastest_df1
# Out:
#       index           站點名稱                 更新時間  行政區              地址  總數  可借  \
# 0         0         中429公園  2023-12-06 13:57:15  中山區      敬業三路177巷南側  15   2
# 1         1       長春路137巷口  2023-12-06 13:57:15  中山區     民生東路二段134號前  16   4
# 2         2         松江民生路口  2023-12-06 13:57:15  中山區        松江路208號前  17   5
# 3         3       松江路132巷口  2023-12-06 13:57:15  中山區       吉林路100號對側  14   8
# 4         4         長春吉林路口  2023-12-06 13:57:15  中山區        長春路120號前  10   2
# ...     ...            ...                  ...  ...             ...  ..  ..
# 1319   1319         南京龍江路口  2023-12-06 14:06:16  中山區     南京東路三段121號前  15   9
# 1320   1320   撫順街41巷(崇德宮前)  2023-12-06 14:06:16  中山區    撫順街41巷1-7號對側  19   4
# 1321   1321    臺北市立圖書館大直分館  2023-12-06 14:06:16  中山區        大直街28號對側  20   7
# 1322   1322    捷運大直站(1號出口)  2023-12-06 14:06:16  中山區      北安路535之2號旁  27  18
# 1323   1323  捷運松江南京站(4號出口)  2023-12-06 14:06:16  中山區  松江路95-1至109號前方  32   2
#
#       可還
# 0     13
# 1     12
# 2     12
# 3      6
# 4      8
# ...   ..
# 1319   6
# 1320  15
# 1321  13
# 1322   9
# 1323  30
#
# [1324 rows x 8 columns]
